# %% [markdown]
# ### ***727723EUAI109 : Sanjay M***

# %% [markdown]
# ### ***Skill Builder : 3***

# %%
y_ = 0.6
y = 1
w = 0.5
x = 2

dLdy_ = 2 * (y_ - y)
dy_dw = x
dL_dw = dLdy_ * dy_dw

print(f'dL/dy_hat = {dLdy_}')
print(f'dy_hat/dw = {dy_dw}')
print(f'dL/dw = {dL_dw}')
# Out:
# dL/dy_hat = -0.8
# dy_hat/dw = 2
# dL/dw = -1.6
