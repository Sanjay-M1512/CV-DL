# %% [markdown]
# ### ***727723EUAI109 : Sanjay M***

# %% [markdown]
# ### ***Skill Builder : 1***

# %%
xt = 2
ht_prev = 1
Wx = 0.5
Wh = 0.8
b = 0.1

ht = (Wx * xt) + (Wh * ht_prev) + b
print(f"Hidden state hₜ = {ht}")
# Out:
# Hidden state hₜ = 1.9000000000000001
