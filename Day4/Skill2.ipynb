# %% [markdown]
# ### ***727723EUAI109 : Sanjay M***

# %% [markdown]
# ### ***Skill Builder : 2***

# %%
ft = 0.7
it = 0.6
Ct_candidate = 0.5
Ct_prev = 1

Ct = (ft * Ct_prev) + (it * Ct_candidate)
print(f"New cell state Cₜ = {Ct}")
# Out:
# New cell state Cₜ = 1.0
